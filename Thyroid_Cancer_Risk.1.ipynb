# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("thyroid_cancer_risk_data.csv")
df
# Out:
#         Patient_ID  Age  Gender  Country       Ethnicity Family_History  \
# 0                1   66    Male   Russia       Caucasian             No
# 1                2   29    Male  Germany        Hispanic             No
# 2                3   86    Male  Nigeria       Caucasian             No
# 3                4   75  Female    India           Asian             No
# 4                5   35  Female  Germany         African            Yes
# ...            ...  ...     ...      ...             ...            ...
# 212686      212687   58  Female    India           Asian             No
# 212687      212688   89    Male    Japan  Middle Eastern             No
# 212688      212689   72  Female  Nigeria        Hispanic             No
# 212689      212690   85  Female   Brazil  Middle Eastern             No
# 212690      212691   46  Female    Japan  Middle Eastern             No
#
#        Radiation_Exposure Iodine_Deficiency Smoking Obesity Diabetes  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212691 entries, 0 to 212690
# Data columns (total 17 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Patient_ID           212691 non-null  int64
#  1   Age                  212691 non-null  int64
#  2   Gender               212691 non-null  object
#  3   Country              212691 non-null  object
#  4   Ethnicity            212691 non-null  object
#  5   Family_History       212691 non-null  object
#  6   Radiation_Exposure   212691 non-null  object
#  7   Iodine_Deficiency    212691 non-null  object
#  8   Smoking              212691 non-null  object
#  9   Obesity              212691 non-null  object
#  10  Diabetes             212691 non-null  object
#  11  TSH_Level            212691 non-null  float64
#  12  T3_Level             212691 non-null  float64
#  13  T4_Level             212691 non-null  float64
# ...

# %%
df.describe()
# Out:
#          Patient_ID            Age      TSH_Level       T3_Level  \
# count  212691.00000  212691.000000  212691.000000  212691.000000
# mean   106346.00000      51.918497       5.045102       2.001727
# std     61398.74739      21.632815       2.860264       0.866248
# min         1.00000      15.000000       0.100000       0.500000
# 25%     53173.50000      33.000000       2.570000       1.250000
# 50%    106346.00000      52.000000       5.040000       2.000000
# 75%    159518.50000      71.000000       7.520000       2.750000
# max    212691.00000      89.000000      10.000000       3.500000
#
#             T4_Level    Nodule_Size
# count  212691.000000  212691.000000
# mean        8.246204       2.503403
# std         2.164188       1.444631
# min         4.500000       0.000000
# 25%         6.370000       1.250000
# 50%         8.240000       2.510000
# 75%        10.120000       3.760000
# max        12.000000       5.000000

# %%
#Missing Values
df.isnull().sum()
# Out:
# Patient_ID             0
# Age                    0
# Gender                 0
# Country                0
# Ethnicity              0
# Family_History         0
# Radiation_Exposure     0
# Iodine_Deficiency      0
# Smoking                0
# Obesity                0
# Diabetes               0
# TSH_Level              0
# T3_Level               0
# T4_Level               0
# Nodule_Size            0
# Thyroid_Cancer_Risk    0
# Diagnosis              0
# dtype: int64

# %%
#df.shape
df.columns
# Out:
# Index(['Patient_ID', 'Age', 'Gender', 'Country', 'Ethnicity', 'Family_History',
#        'Radiation_Exposure', 'Iodine_Deficiency', 'Smoking', 'Obesity',
#        'Diabetes', 'TSH_Level', 'T3_Level', 'T4_Level', 'Nodule_Size',
#        'Thyroid_Cancer_Risk', 'Diagnosis'],
#       dtype='object')

# %%
# Duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates()
df.shape
# Out:
# (212691, 17)

# %%
df.dtypes
# Out:
# Patient_ID               int64
# Age                      int64
# Gender                  object
# Country                 object
# Ethnicity               object
# Family_History          object
# Radiation_Exposure      object
# Iodine_Deficiency       object
# Smoking                 object
# Obesity                 object
# Diabetes                object
# TSH_Level              float64
# T3_Level               float64
# T4_Level               float64
# Nodule_Size            float64
# Thyroid_Cancer_Risk     object
# Diagnosis               object
# dtype: object

# %%
#Gender
number_count = df['Gender'].value_counts()
number_count
# Out:
# Gender
# Female    127527
# Male       85164
# Name: count, dtype: int64

# %%
# age sorted
df.sort_values(by = 'Age')
# Out:
#         Patient_ID  Age  Gender      Country       Ethnicity Family_History  \
# 210886      210887   15    Male       Brazil       Caucasian             No
# 106203      106204   15    Male        India       Caucasian             No
# 90096        90097   15    Male        India  Middle Eastern             No
# 147251      147252   15  Female       Brazil       Caucasian             No
# 56390        56391   15  Female        Japan        Hispanic             No
# ...            ...  ...     ...          ...             ...            ...
# 18007        18008   89  Female        India       Caucasian             No
# 5                6   89    Male           UK         African             No
# 161696      161697   89    Male        Japan       Caucasian             No
# 44547        44548   89  Female        India         African            Yes
# 44592        44593   89  Female  South Korea        Hispanic            Yes
#
# ...

# %%
# Count the occurrences of each country
country_counts = df['Country'].value_counts()
country_counts
# Out:
# Country
# India          42496
# China          31978
# Nigeria        31918
# Brazil         21413
# Russia         21297
# Japan          16867
# South Korea    14965
# UK             10642
# USA            10558
# Germany        10557
# Name: count, dtype: int64

# %%
# This shows the distribution of risk categories after mapping.
risk_mapping = {'Low':0,'Medium':1,'High':2}
df['Risk_Score'] = df['Thyroid_Cancer_Risk'].map(risk_mapping)
df['Risk_Score'].value_counts()
# Out:
# Risk_Score
# 0    108388
# 1     72400
# 2     31903
# Name: count, dtype: int64

# %%
risk_mapping = {'Low':0, 'Medium':1, 'High':2}
df['Risk_Score'] = df['Thyroid_Cancer_Risk'].map(risk_mapping)

selected_columns = ['TSH_Level','T3_Level','T4_Level','Risk_Score','Nodule_Size']
corr = df[selected_columns].corr()
corr
# Out:
#              TSH_Level  T3_Level  T4_Level  Risk_Score  Nodule_Size
# TSH_Level     1.000000  0.000335 -0.000795    0.002494     0.000416
# T3_Level      0.000335  1.000000 -0.004069   -0.000348    -0.001799
# T4_Level     -0.000795 -0.004069  1.000000    0.002761    -0.001860
# Risk_Score    0.002494 -0.000348  0.002761    1.000000    -0.000352
# Nodule_Size   0.000416 -0.001799 -0.001860   -0.000352     1.000000

# %%
# Barplot
counts_of_risk = df['Risk_Score'].value_counts()
sns.barplot(x=counts_of_risk.index, y=counts_of_risk.values,palette='Set2',edgecolor = "black")
plt.title('Risk to get Thyroid cancer',fontweight='bold')
plt.ylabel('Count',fontweight='bold')
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_9180\589923868.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=counts_of_risk.index, y=counts_of_risk.values,palette='Set2',edgecolor = "black")

# %% [markdown]
# Risk Score Distribution
#
# The chart shows how many people fall into each thyroid cancer risk group:
#
# Low Risk (Score 0): Most patients are in this group.
#
# Medium Risk (Score 1): A fair number of patients are here.
#
# High Risk (Score 2): Only a few patients are in this group.

# %%
sns.countplot(data=df, x='Thyroid_Cancer_Risk', hue='Family_History',palette='Set2',edgecolor = "black")
plt.title('Thyroid Cancer Risk by Family History',fontweight='bold')
plt.show()

# %% [markdown]
#  Main Observations:
#
# Low Risk: Most individuals without a family history fall into this category. The green bar (no family history) is much taller than the orange one (with family history).
#
# Medium Risk: The difference narrows. People with and without family history are more evenly distributed, but those without still slightly outnumber.
#
# High Risk: The trend flips—more individuals with a family history are in the high-risk group than those without.

# %%
plt.figure(figsize=(8,6))
sns.countplot(data=df, x='Ethnicity', hue='Thyroid_Cancer_Risk',palette='Set2',edgecolor = "black")
plt.title('Cancer Risk Levels Across Regions',fontweight='bold')
plt.show()

# %% [markdown]
# Key Observations:
#
# Caucasian group has the highest overall counts across all risk levels—especially in the Low and Medium categories.
#
# Asian and African groups show similar distributions, with a noticeable presence in the High risk category.
#
# Hispanic individuals have moderate counts in Low and Medium risk levels, but fewer in High risk.
#
# Middle Eastern group has the lowest total count, but interestingly, the High risk category dominates among them.

# %%
plt.figure(figsize=(12,6))
sns.countplot(data=df, x='Country', hue='Thyroid_Cancer_Risk',palette='Set2',edgecolor = "black")
plt.title('Cancer Risk Levels Across Countries',fontweight='bold')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Key Insights:
#
# USA and India show the highest overall counts, especially in the Low and Medium risk categories.
#
# South Korea and Japan have relatively high counts in the High risk category, suggesting a greater proportion of individuals at serious risk.
#
# Nigeria and Brazil display lower overall counts, with a more balanced distribution across all three risk levels.
#
# Germany, UK, and Russia lean toward Medium risk dominance, while China has a fairly even spread.
#
# What This Might Indicate:
#
# Healthcare access and screening: Countries like the USA and India may have broader screening programs, leading to higher detection rates in Low and Medium categories.
#
# Environmental or genetic factors: The elevated High risk counts in East Asian countries (South Korea, Japan) could point to regional health patterns worth investigating.
#
# Population size and data representation: Larger countries may naturally show higher counts, but the proportions between risk levels still reveal meaningful trends.

# %%
#coorelation
corr_matrix = df.corr(numeric_only=True)
print(corr_matrix)
# Out:
#              Patient_ID       Age  TSH_Level  T3_Level  T4_Level  Nodule_Size  \
# Patient_ID     1.000000  0.002691   0.000383  0.001934 -0.000982     0.000458
# Age            0.002691  1.000000  -0.000925 -0.001013 -0.002373    -0.001489
# TSH_Level      0.000383 -0.000925   1.000000  0.000335 -0.000795     0.000416
# T3_Level       0.001934 -0.001013   0.000335  1.000000 -0.004069    -0.001799
# T4_Level      -0.000982 -0.002373  -0.000795 -0.004069  1.000000    -0.001860
# Nodule_Size    0.000458 -0.001489   0.000416 -0.001799 -0.001860     1.000000
# Risk_Score     0.000635  0.003255   0.002494 -0.000348  0.002761    -0.000352
#
#              Risk_Score
# Patient_ID     0.000635
# Age            0.003255
# TSH_Level      0.002494
# T3_Level      -0.000348
# T4_Level       0.002761
# Nodule_Size   -0.000352
# Risk_Score     1.000000

# %%
sns.histplot(df['T3_Level'], kde=True, color='green',palette='Set2',edgecolor = "black")#t3 level
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_9180\1805704606.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df['T3_Level'], kde=True, color='green',palette='Set2',edgecolor = "black")#t3 level
# <Axes: xlabel='T3_Level', ylabel='Count'>

# %% [markdown]
# Key Observations:
#
# The x-axis represents T3 levels, ranging from about 0.5 to 3.5.
#
# The y-axis shows the count of individuals with each T3 level, peaking just below 5000.
#
# The green histogram bars show how frequently each T3 level occurs.
#
# The line plot mirrors the histogram’s shape, helping us see the overall trend more clearly.

# %%
sns.histplot(df['T4_Level'], kde=True, color='orange',palette='Set2',edgecolor="black")
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_9180\582467331.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df['T4_Level'], kde=True, color='orange',palette='Set2',edgecolor="black")
# <Axes: xlabel='T4_Level', ylabel='Count'>

# %% [markdown]
# Key Observations:
#
# The x-axis spans T4 levels from about 4.5 to 12, which likely covers the typical clinical range.
#
# The y-axis shows the count of individuals at each T4 level, peaking just below 4000.
#
# The light orange bars represent the frequency of each T4 level.
#
# The darker orange line smooths out the distribution, making trends easier to spot.

# %%
### Age:
sns.histplot(data = df, x ='Age', bins = 10, kde = True)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Histogram of Age')
plt.show()

# %% [markdown]
# Key Observations:
#
# The x-axis spans ages from around 10 to 100, covering a wide demographic range.
#
# The y-axis shows frequency, with counts reaching up to 25,000 individuals in some age groups.
#
# The bars represent how many people fall into each age interval.
#
# The smooth blue line overlays the histogram, showing the overall trend—likely a kernel density estimate.

# %%
##Outlier 
for col in df.select_dtypes(include=np.number).columns:
    plt.figure(figsize=(6,3))
    sns.boxplot(data=df, x=col)
    plt.show()#Hormone Level & Diagnosis

# %%
# Heatmap for Correlations
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True),annot=True, cmap="coolwarm",fmt =".2f")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# Key Observations:
#
# Diagonal values are all 1.00: That’s expected, since each variable is perfectly correlated with itself.
#
# Off-diagonal values are all 0.00: This means there’s no linear correlation between any pair of different variables in this dataset.

# %%
# Nodule Size vs. Diagnosis
plt.figure(figsize=(8,5))
sns.violinplot(x="Diagnosis", y = "Nodule_Size", data=df , palette="pastel")
plt.title("Distribution of Nodule Size by diagnosis")
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_9180\1538715398.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x="Diagnosis", y = "Nodule_Size", data=df , palette="pastel")

# %% [markdown]
# Key Takeaways:
#
# Similar distributions: The shape of both violins is quite similar, meaning the spread and density of nodule sizes are comparable for benign and malignant cases.
#
# Overlap in size: There's no clear separation in nodule size between the two categories. This suggests that nodule size alone may not be a reliable indicator for distinguishing between benign and malignant nodules.
#
# Median and IQR: The central box plot inside each violin shows the median and interquartile range (IQR). If these are close between the two groups, it reinforces that the central tendency and variability are alike.

# %%
# Age Distribution
sns.set_theme(style = "darkgrid")
plt.figure(figsize=(8,5))
sns.histplot(df["Age"], bins=30, kde=True, color="orange")
plt.title("Age Distribution of Patients")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# Key Insights:
#
# Wide age range: Patients span from around age 10 to 90, showing that the dataset includes both young and elderly individuals.
#
# Relatively uniform distribution: Most age groups have a fairly consistent number of patients, suggesting no major age bias in the data.
#
# Fewer patients at extremes: There are noticeable dips in patient count at the youngest (10–20) and oldest (80–90) age ranges. This could reflect real-world trends—fewer young people with nodules, and fewer elderly patients being diagnosed or included in the dataset.

# %%
# Gender Distribution
plt.figure(figsize=(6,4))
sns.countplot(x="Gender", data=df,palette="coolwarm")
plt.title("Gender Distribution")
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_9180\2608252669.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Gender", data=df,palette="coolwarm")

# %% [markdown]
# Key Insights:
#
# Female count is significantly higher than male count.
#
# The imbalance suggests that the dataset is skewed toward female participants.

# %%
# Family History vs. Diagnosis
plt.figure(figsize=(6,4))
sns.countplot(x="Family_History", hue="Diagnosis", data=df, palette="viridis")
plt.title("Impact of Family History on thyroid cancer Diagnosis")
plt.show()

# %% [markdown]
# Key Insights:
#
# No Family History:
# Benign cases dominate: Around 120,000.
# Malignant cases are fewer: Around 30,000.
#
# Yes to Family History:
# Benign cases drop: Around 60,000.
# Malignant cases stay similar: Around 30,000.

# %%
coun = df.groupby('Country')['Gender'].value_counts(normalize = True).unstack().reset_index()
for index, row in coun.iterrows():
    # Get the gender columns (assumes first column is 'Country')
    gender_labels = row.index[1:]
    gender_values = row[gender_labels].values
    
    plt.figure(figsize=(6,6))
    plt.pie(gender_values, labels=gender_labels, autopct='%1.1f%%', startangle=90)
    plt.title(f"Gender Distribution in {row['Country']}")
    plt.axis('equal') 
    plt.show()

# %%
# Plot a pie chart
plt.figure(figsize=(8, 8))
plt.pie(country_counts, 
        labels=country_counts.index, 
        autopct='%1.1f%%',  # Display percentage on the chart
        startangle=140)      # Starting angle for better visual layout

plt.title('Country Distribution')
plt.axis('equal')  # Equal aspect ratio ensures the pie is drawn as a circle
plt.show()

# %% [markdown]
# Key Insights:
#
# India leads with 20.0%, making it the most represented country.
#
# China and Nigeria follow closely, each with 15.0%.
#
# Brazil, Russia, Japan, South Korea, USA, and Germany have smaller shares ranging from 10.1% to 5.0%.
#
# UK has 0.0%, meaning it’s either not represented or excluded from this dataset.
